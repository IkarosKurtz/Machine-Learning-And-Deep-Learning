# %% [markdown]
# # Universidad Autónoma de Aguascalientes
#
# # Departamento: Ciencias de la Computación
#
# # Carrera: Ingeniería en Computación Inteligente
#
# ## Curso: Aprendizaje Automático
#
# ## Maestro: Dr. Francisco Javier Luna Rosas
#
# ## Alumno: Carlos Leonardo Cruz Ortiz
#
# ### Semestre: Enero-Junio del 2026

# %% [markdown]
# # PRACTICA No. 5. El Perceptron de Frank Rosenblatt para Clasificar la Flor de Iris.
#
# ### En esta practica implementaremos el Perceptron de Frank Rosenblatt para Clasificar la Flor de Iris. Clasificaremos dos clases de la Flor de Iris (Setosa y Versicolor), las caracteristicas que tomaremos en cuenta son: longitud del petalo y longitud del sefalo.

# %% [markdown]
# ## Paso 1: Importar librerías necesarias

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import Perceptron

# %% [markdown]
# ## Paso 2: Cargamos el dataset

# %%
df = pd.read_csv('../data/iris.csv', delimiter=';', decimal=',')
print(df.shape)
print(df.head())
# Out:
# (150, 5)
#   s.largo s.ancho p.largo p.ancho    tipo
# 0     5.1     3.5     1.4     0.2  setosa
# 1     4.9     3.0     1.4     0.2  setosa
# 2     4.7     3.2     1.3     0.2  setosa
# 3     4.6     3.1     1.5     0.2  setosa
# 4     5.0     3.6     1.4     0.2  setosa

# %% [markdown]
# ## Paso 3: Extraemos el largo sepal y el largo del pétalo en las columnas 0 y 2. Usaremos solo Setosa y Versicolor

# %%
X = df.iloc[0:100, [0, 2]].values
#print(X)

# %% [markdown]
# ## Paso 4: Graficamos el largo del sepal y el largo del petalo de las flores: Setosas y Versicolores.

# %%
# Graftcamos Datos
plt.scatter(X[:50, 0], X[:50, 1], color='red', marker='o', label='setosa')
plt.scatter(X[50:100, 0], X[50:100, 1], color='blue', marker='x', label='versicolor')

# Grafica etiquetas
plt.xlabel('sepal length (cm)')
plt.ylabel('petal length (cm)')

# Graficamos la leyenda
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## Paso 5: Sleccionamos Setsoa y Versicolor.

# %%
y = df.iloc[0:100, 4].values
# print(y)

# %% [markdown]
# ## Paso 6: Convertimos etiquetas a numeros.

# %%
y = np.where(y == 'setosa', -1, 1)
#print (y)

# %% [markdown]
# ## Paso 7: Creamos un objeto de tipo Perceptron

# %%
perceptron = Perceptron()

# %% [markdown]
# ## Paso 8: Entrenamos el perceptron para la flor de iris.

# %%
perceptron.fit(X, y)
# Out:
# Perceptron()

# %% [markdown]
# ## Paso 9: Predecimos el tipo de flor.

# %%
perceptron.predict([
  [5.7, 4.1],
  [5.1, 1.4]
])
# Out:
# array([ 1, -1])

# %% [markdown]
# ## Conclusiones
#
# ### En esta practica implementamos el Perceptron de Frank Rosenblatt para Clasificar la Flor de Iris. Clasificaremos dos clases de la Flor de Iris (Setosa y Versicolor), las caracteristicas que consideramos son: longitud del petalo y longitud del sefalo.

# %% [markdown]
# ## Referencias
#
# ### SCIKIT-LEARN (Machine Learning in Python 2025). URL: https://scikit-learn.org/stable/modules/linear_model.html#perceptron (Ultimo acceso febrero 2025).
# ### Octavio Gutiérrez (2025). El Perceptron Paso a Paso con Python: https://www.youtube.com/watch?v=dkhXGTersPO (Ultimo acceso, Febrero de 2025).
# ### Sebastian Raschka, Vahid Mirjalili (2019). Machine Learning, Editorial Marcombo, Madrid, Espafia. URL: www.marcombo.info. ISBN: 978-84-267-2720-6
# ### OpenAl, (2025). ChatGPT (versiön GPT-4.1) [Modelo de lenguaje Grande].https://chat.openai.com/
